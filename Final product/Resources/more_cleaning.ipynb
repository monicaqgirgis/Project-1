# %%
# Dependencies and Setup
import pandas as pd

# %%
# Load the dataset
file_path = "/Users/alyssaberridge/Desktop/Projects/Project-1/Resources/Cleaned Cancer Project .csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())

# Replace specific values in the 'age' column
df['Age'] = df['Age'].replace({
    0: '<1 year', 
    1: '1-4 years', 
    2: '5-9 years', 
    3: '10-14 years', 
    4: '15-19 years', 
    5: '20-24 years', 
    6: '25-29 years', 
    7: '30-34 years', 
    8: '35-39 years', 
    9: '40-44 years', 
    10: '45-49 years', 
    11: '50-54 years', 
    12: '55-59 years', 
    13: '60-64 years', 
    14: '65-69 years', 
    15: '70-74 years', 
    16: '75-79 years', 
    17: '80-84 years', 
    18: '85+', 
    19: 'unknown age'
})

# display the modified DataFrame
print(df.head())

# Save the modified DataFrame back to a new CSV file
df.to_csv("/Users/alyssaberridge/Desktop/Projects/Project-1/Resources/Modified_Cleaned_Cancer_Project.csv", index=False)
# Out:
#     Race          Sex  Year          Age  \
# 0  White  Male/Female  2000      <1 year
# 1  White  Male/Female  2000    1-4 years
# 2  White  Male/Female  2000    5-9 years
# 3  White  Male/Female  2000  10-14 years
# 4  White  Male/Female  2000  15-19 years
#
#    In the natural position of diagnosis  Localized  Regional  Distant  \
# 0                                     1          3         1        0
# 1                                     0          2         0        0
# 2                                     0         43        13        0
# 3                                     0        247        72       14
# 4                                     8        484       179       45
#
#    Unknown Stage  Total Documented Cases  \
# 0              0                       5
# 1              0                       2
# 2              0                      56
# 3              4                     337
# 4             21                     737
#
# ...

# %%
# Load the dataset
file_path = "/Users/alyssaberridge/Desktop/Projects/Project-1/Resources/Modified_Cleaned_Cancer_Project.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())

# Replace specific values in the 'age' column
df['Age'] = df['Age'].replace({
 
   '1-4 years' : '01-04 years', 
    '5-9 years' : '05-09 years', 
  
})

# display the modified DataFrame
print(df.head())

# Save the modified DataFrame back to a new CSV file
df.to_csv("/Users/alyssaberridge/Desktop/Projects/Project-1/Resources/Modified_Cleaned_Cancer_Project.csv", index=False)
# Out:
#     Race          Sex  Year          Age  \
# 0  White  Male/Female  2000      <1 year
# 1  White  Male/Female  2000    1-4 years
# 2  White  Male/Female  2000    5-9 years
# 3  White  Male/Female  2000  10-14 years
# 4  White  Male/Female  2000  15-19 years
#
#    In the natural position of diagnosis  Localized  Regional  Distant  \
# 0                                     1          3         1        0
# 1                                     0          2         0        0
# 2                                     0         43        13        0
# 3                                     0        247        72       14
# 4                                     8        484       179       45
#
#    Unknown Stage  Total Documented Cases  \
# 0              0                       5
# 1              0                       2
# 2              0                      56
# 3              4                     337
# 4             21                     737
#
# ...

# %%
# available columns
df.columns
# Out:
# Index(['Race', 'Sex', 'Year', 'Age', 'In the natural position of diagnosis',
#        'Localized', 'Regional', 'Distant', 'Unknown Stage',
#        'Total Documented Cases', 'Blanks/ Meets NO requirements as whole'],
#       dtype='object')

# %%
# Display the first few rows before deleting the column
print("Before deleting 'Total Documented Cases' column:")
print(df.head())

# Drop the 'Total Documented Cases' column
df = df.drop(columns=['Total Documented Cases'])

# Display the first few rows after deleting the column
print("\nAfter deleting 'Total Documented Cases' column:")
print(df.head())

# Save the modified DataFrame back to a new CSV file
df.to_csv("/Users/alyssaberridge/Desktop/Projects/Project-1/Resources/Modified_Cleaned_Cancer_Project.csv", index=False)
# Out:
# Before deleting 'Total Documented Cases' column:
#     Race          Sex  Year          Age  \
# 0  White  Male/Female  2000      <1 year
# 1  White  Male/Female  2000  01-04 years
# 2  White  Male/Female  2000  05-09 years
# 3  White  Male/Female  2000  10-14 years
# 4  White  Male/Female  2000  15-19 years
#
#    In the natural position of diagnosis  Localized  Regional  Distant  \
# 0                                     1          3         1        0
# 1                                     0          2         0        0
# 2                                     0         43        13        0
# 3                                     0        247        72       14
# 4                                     8        484       179       45
#
#    Unknown Stage  Total Documented Cases  \
# 0              0                       5
# 1              0                       2
# 2              0                      56
# 3              4                     337
# ...
